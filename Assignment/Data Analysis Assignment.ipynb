# %% [markdown]
# ## Assignment: Data Analysis and Preprocessing
#
# ####  Objective: The objective of this assignment is to perform data analysis and preprocessing on a given dataset to prepare it for further analysis and modeling.
#
# #### Instructions:
#
# * Step 1: Data Exploration
#
# Obtain the dataset for this assignment. If not provided, you can choose a publicly available dataset relevant to your course or topic.
#
# Load the dataset into a Jupyter Notebook or any preferred data analysis environment.
#
# Provide a brief description of the dataset, including the number of records, features, and the data types of each feature.
#
# Display the first few rows of the dataset to get an initial understanding of the data.
#
# * Step 2: Data Cleaning
#
# Identify and handle missing values in the dataset. Explain the strategy used for dealing with missing data (e.g., imputation, removal).
#
# Check for duplicate records and remove them if necessary.
#
# Address any outliers in the dataset, if present. Explain the approach you used to identify and handle outliers.
#
# * Step 3: Data Preprocessing
#
# Perform feature selection by identifying and justifying which features are relevant for your analysis. You can use techniques like correlation analysis or domain knowledge.
#
# Perform feature engineering if necessary. Create new features or transform existing ones to better represent the data. Explain the rationale behind the feature engineering choices.
#
# * Step 4: Data Analysis
#
# Conduct a descriptive analysis of the data, including summary statistics, distributions, and visualizations (e.g., histograms, box plots) for key features.
#
# Explore relationships between variables using appropriate visualizations and statistical tests.
#
# * Step 5: Data Preparation for Modeling
#
# If your dataset contains categorical variables, encode them appropriately (e.g., one-hot encoding or label encoding).
#
# Scale or standardize the numeric features, as necessary, to prepare the data for machine learning algorithms.
#
# * Step 6: Report and Conclusions
#
# Summarize the key findings from your data analysis, including any interesting insights or patterns discovered.
#
# Provide any recommendations for further analysis or modeling based on your findings.
#
# * Submission:
#
# Students should submit their completed Jupyter Notebook or a report detailing the steps they followed in the data analysis and preprocessing process. Additionally, they should provide any code used, visualizations, and explanations for their decisions at each step.
#
# * Grading:
#
# The assignment can be graded based on the following criteria:
#
# Data exploration and understanding (10%)
# Data cleaning (20%)
# Data preprocessing (20%)
# Data analysis (20%)
# Data preparation for modeling (15%)
# Report and conclusions (15%)

# %% [markdown]
# ## Data Set
#
# Loan Default
#
# https://drive.google.com/file/d/1L8xknu-i-70NdJkSg_TeyidZUef969eq/view?usp=sharing
#
# Data Features :
#
# Data columns (total 34 columns):
#  #   Column
# ---  ------                     --------------   -----
#  0   ID
#
#  1   year
#
#  2   loan_limit
#
#  3   Gender
#
#  4   approv_in_adv
#
#  5   loan_type
#
#  6   loan_purpose
#
#  7   Credit_Worthiness
#
#  8   open_credit
#
#  9   business_or_commercial
#
#  10  loan_amount
#
#  11  rate_of_interest
#
#  12  Interest_rate_spread
#
#  13  Upfront_charges
#
#  14  term
#
#  15  Neg_ammortization
#
#  16  interest_only
#
#  17  lump_sum_payment
#
#  18  property_value
#
#  19  construction_type
#
#  20  occupancy_type
#
#  21  Secured_by
#
#  22  total_units
#
#  23  income
#
#  24  credit_type
#
#  25  Credit_Score
#
#  26  co-applicant_credit_type
#
#  27  age
#
#  28  submission_of_application
#
#  29  LTV
#
#  30  Region
#
#  31  Security_Type
#
# #### 32  Status                 (Target)
#
#  33  dtir1
