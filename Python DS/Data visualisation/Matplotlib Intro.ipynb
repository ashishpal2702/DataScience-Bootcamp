# %% [markdown]
# ![image.png](attachment:9ad33963-b595-40f8-9af8-077f861f6a6e.png)

# %% [markdown]
# # References
#
# ## Matplotlib
#  -- https://matplotlib.org/stable/
#
# ## Plot Types
# -- https://matplotlib.org/stable/plot_types/index.html
#
# ## Cheatsheet
# -- https://matplotlib.org/cheatsheets/

# %% [markdown]
# ## 1.  Getting Started

# %%
## https://matplotlib.org/stable/users/getting_started/index.html

# %% [markdown]
# ![image.png](attachment:a78af358-de13-4371-830a-4d7e36cbc7f2.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib as mpl

# %%
fig, ax = plt.subplots()

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.
ax.plot([2, 3, 4, 5], [5, 8, 9, 10])
ax.plot([1, 8, 9, 10], [2, 3, 4, 4])

# %% [markdown]
# ## Scatter Plot

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.scatter([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.
ax.scatter([2, 3, 4, 5], [5, 8, 9, 10])
ax.scatter([1, 8, 9, 10], [2, 3, 4, 4])

# %% [markdown]
# ## Bar Plot

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.bar([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.
#ax.bar([2, 3, 4, 5], [5, 8, 9, 10])
#ax.bar([1, 8, 9, 10], [2, 3, 4, 4])
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Histogram

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.hist([1, 2, 3, 5, 1, 4, 2, 3])
# Out:
# (array([2., 0., 2., 0., 0., 2., 0., 1., 0., 1.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.boxplot([1, 2, 3, 5, 1, 4, 2, 3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11bdeaf70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x11bdf95e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x11bdeaca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x11bdf9af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11bdf9df0>],
#  'means': []}

# %% [markdown]
# ## 2. Types of Charts

# %%
## https://matplotlib.org/stable/plot_types/index.html

# %% [markdown]
# ![image.png](attachment:fa5a2c0e-32f2-4e3e-9bde-1bb40d5d33ad.png)

# %% [markdown]
# * 1. Line Charts
# * 2. Scatter plot
# * 3. Bubble chart
# * 4. Bar Graphs
# * 5. Histograms
# * 6. Box plot
# * 7. Waterfall chart
# * 8. Venn diagram
# * 9. Tree map
# * 10. 100% stacked bar chart
# * 11. Marginal plots
#
#
# * --- Subplots
#  * Additional
#      1. Count
#      2. Swarm
#      3. Violin
#      4. Strip
#      5. Pairplot
#      6. Heatmap
#      7. REGPLOT
#      8. LMPLOT

# %%
## Boxplot
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data:
np.random.seed(10)
D = np.random.normal((3, 5, 4), (1.25, 1.00, 1.25), (100, 3))

# plot
fig, ax = plt.subplots()
VP = ax.boxplot(D, positions=[2, 4, 6], widths=1.5, patch_artist=True,
                showmeans=False, showfliers=False,
                medianprops={"color": "white", "linewidth": 0.5},
                boxprops={"facecolor": "C0", "edgecolor": "white",
                          "linewidth": 0.5},
                whiskerprops={"color": "C0", "linewidth": 1.5},
                capprops={"color": "C0", "linewidth": 1.5})

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# ## 3.Basics
# https://matplotlib.org/stable/users/explain/quick_start.html#quick-start
